# %% [markdown]
# # 7 - Model evaluation
# #   🗺️ --> 📈 🎯

# %% [markdown]
# **OBJECTIVE:** This represents a critical step of any "good" ML research and it consists of evaluating the model's performance on new data (i.e. test data) for which we have high quality annotations.
#
# **INPUT:**
# - `test data`= path to directory where predicted labels (output from step 5) are stored.
# - `path_to_detected_boxes`= path to tile index that can be used to convert to YOLO formatted bounding box coordinates to UTM
#
# **OUTPUT:**
# - a geoJSON file that includes all predicted bounding boxes with class name and class probability

# %%
annotator_ID=99 # change this to your folder ID

path_to_model="/content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/train/99/seedlings_YOLOn_img640/weights/best.pt"
path_to_yaml= "/content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/train/99/train_config.yaml"

#path_to_tile_index=path_to_predicted+ "/krakstad_202304_sun_tile_index.shp"#+os.path.basename(path_to_predicted)+".shp"
#buffer_size_m=1

# %% [markdown]
# ## 7.1 load required libraries

# %%
# !pip install geopandas
# %pip install ultralytics
import ultralytics
ultralytics.checks()

# general libraries
import os, glob
from pathlib import Path

# Geospatial libraries
import geopandas as gpd
from osgeo import gdal, osr
from shapely.geometry import Polygon
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.9/107.7 GB disk)

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 7.2 Validate using YOLOv8 builtin "val" function
# this provides a standard method for validation of bounding box detectors

# %%
#!zip -r /content/drive/MyDrive/NOVA_course_deep_learning_2/NOVA_Deep_Learning.zip /content/drive/MyDrive/NOVA_course_deep_learning_2
# Out:
# Scanning files ...... .
#   adding: content/drive/MyDrive/NOVA_course_deep_learning_2/ (stored 0%)
#   adding: content/drive/MyDrive/NOVA_course_deep_learning_2/data/ (stored 0%)
#   adding: content/drive/MyDrive/NOVA_course_deep_learning_2/data/orthomosaics/ (stored 0%)
#   adding: content/drive/MyDrive/NOVA_course_deep_learning_2/data/orthomosaics/test_data/ (stored 0%)
#   adding: content/drive/MyDrive/NOVA_course_deep_learning_2/data/orthomosaics/test_data/krakstad_202304_sun.tif
#
#
# zip error: Interrupted (aborting)

# %%
# !yolo val model=$path_to_model data=$path_to_yaml split='test' imgsz=640 project="/content/drive/MyDrive/NOVA_course_deep_learning_2/data/testing" name="test_eval_full" conf=0.171
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/labels... 228 images, 0 backgrounds, 31 corrupt: 100% 228/228 [01:03<00:00,  3.60it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_11_23.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0109]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_11_24.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0079]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_12_21.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0065]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_12_22.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0076]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_12_24.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0108      1.0097]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_13_22.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0026]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_13_23.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0135]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_14_22.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0188]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_15_21.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.001]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_15_24.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0086      1.0073]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_16_23.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.009]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_16_24.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0133      1.0099]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_17_23.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0134]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_18_22.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.02]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_18_24.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0042        1.03]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_19_26.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0248      1.0055]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_20_25.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.015]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_20_26.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.002      1.0221]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_20_27.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0014]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_21_24.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0153]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_21_26.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0076]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_21_27.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0019]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_22_23.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0013      1.0254]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_22_25.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0131]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_22_26.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0611]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_22_27.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0064]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_23_26.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0031      1.0132]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_24_22.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0044]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_24_23.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0157]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_25_23.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0052]
# val: WARNING ⚠️ /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/images/galbyveien_20230504_sun_25_25.tif: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0014]
# val: New cache created: /content/drive/MyDrive/NOVA_course_deep_learning_2/data/annotated_data/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:49<00:00,  3.81s/it]
#                    all        197       2608       0.63      0.388      0.502      0.157
# Speed: 3.5ms preprocess, 180.9ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /content/drive/MyDrive/NOVA_course_deep_learning_2/data/testing/test_eval_full

# %%
path_to_yaml
# Out:
# '/content/drive/MyDrive/NOVA_course_deep_learning/data/annotated_data/train/3/train_config.yaml'

# %% [markdown]
# ## 7.3 Now let's understand how this is done
# - The predicted boxes are overlayed to the true labels and the IoU is computed.
# - A match is found when the IoU > 0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Building the confusion matrix

# %% [markdown]
# - Compute metrics from confusion matrix

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Precision**: Precision is a measure of how many of the positive predictions made are correct (true positives). The formula for it is:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Recall**: Recall is a measure of how many of the positive cases the classifier correctly predicted, over all the positive cases in the data. It is sometimes also referred to as Sensitivity. The formula for it is:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **F1-score**: F1-Score is a measure combining both precision and recall. It is generally described as the harmonic mean of the two. Harmonic mean is just another way to calculate an “average” of values, generally described as more suitable for ratios (such as precision and recall) than the traditional arithmetic mean. The formula used for F1-score in this case is:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The idea is to provide a single metric that weights the two ratios (precision and recall) in a balanced way, requiring both to have a higher value for the F1-score value to rise. For example, a Precision of 0.01 and Recall of 1.0 would give :
#
# - an arithmetic mean of (0.01+1.0)/2=0.505,
# - F1-score score (formula above) of 2*(0.01*1.0)/(0.01+1.0)=~0.02.
#
#
# This is because the F1-score is much more sensitive to one of the two inputs having a low value (0.01 here). Which makes it great if you want to balance the two.
#
# *Some advantages of F1-score:*
#
# Very small precision or recall will result in lower overall score. Thus it helps balance the two metrics.
# If you choose your positive class as the one with fewer samples, F1-score can help balance the metric across positive/negative samples.
# As illustrated by the first figure in this article, it combines many of the other metrics into a single one, capturing many aspects at once.
